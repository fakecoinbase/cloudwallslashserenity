# %%
import numpy as np
import pandas as pd

from beakerx import *
from beakerx.object import beakerx

# %%
np.random.seed(1)

rows,cols = 5,3
data = np.random.rand(rows,cols) # You can use other random functions to generate values with constraints
tidx = pd.date_range('2019-01-01', periods=rows, freq='MS') # freq='MS'set the frequency of date in months and start from day 1. You can use 'T' for minutes and so on
df = pd.DataFrame(data, columns=['a','b','c'], index=tidx)

# %%
table = TableDisplay(df)
table.setAlignmentProviderForColumn('side', TableDisplayAlignmentProvider.CENTER_ALIGNMENT)
table.setRendererForColumn("size", TableDisplayCellRenderer.getDataBarsRenderer(False))
table.setRendererForType(ColumnType.Double, TableDisplayCellRenderer.getDataBarsRenderer(True))
table.setColumnVisible("price", False)
table.setColumnVisible("fee", False)
table.setColumnVisible("total", False)
table
# Out:
# /opt/conda/lib/python3.7/site-packages/beakerx/tabledisplay/tabledisplay.py:109: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   value = args[0][columnName].get_values()[index]
# /opt/conda/lib/python3.7/site-packages/beakerx/tabledisplay/tabledisplay.py:114: FutureWarning: The 'get_values' method is deprecated and will be removed in a future version. Use '.to_numpy()' or '.array' instead.
#   index_values = args[0].index.get_values()[index]

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

# %%
@interact_manual
def show_articles_more_than(column=['a', 'b'], 
                            x=(10, 20000, 10)):
    return df.loc[df[column] > x]
# Out:
# interactive(children=(Dropdown(description='column', options=('a', 'b'), value='a'), IntSlider(value=10000, de…

# %%
import pandas as pd
import cufflinks as cf
import numpy as np
from IPython.display import display,HTML

# %%
cf.set_config_file(theme='ggplot',sharing='public',offline=True)

# Generating 4 timeseries 
df=cf.datagen.lines(4,1000)
df.iplot()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="77490fb3-7181-4b8d-87b6-d8cd6b3eef3f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("77490fb3-7181-4b8d-87b6-d8cd6b3eef3f")) {
#                     Plotly.newPlot(
#                         '77490fb3-7181-4b8d-87b6-d8cd6b3eef3f',
#                         [{"line": {"color": "rgba(226, 74, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "FZR.XU", "text": "", "type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10", "2015-04-11", "2015-04-12", "2015-04-13", "2015-04-14", "2015-04-15", "2015-04-16", "2015-04-17", "2015-04-18", "2015-04-19", "2015-04-20", "2015-04-21", "2015-04-22", "2015-04-23", "2015-04-24", "2015-04-25", "2015-04-26", "2015-04-27", "2015-04-28", "2015-04-29", "2015-04-30", "2015-05-01", "2015-05-02", "2015-05-03", "2015-05-04", "2015-05-05", "2015-05-06", "2015-05-07", "2015-05-08", "2015-05-09", "2015-05-10", "2015-05-11", "2015-05-12", "2015-05-13", "2015-05-14", "2015-05-15", "2015-05-16", "2015-05-17", "2015-05-18", "2015-05-19", "2015-05-20", "2015-05-21", "2015-05-22", "2015-05-23", "2015-05-24", "2015-05-25", "2015-05-26", "2015-05-27", "2015-05-28", "2015-05-29", "2015-05-30", "2015-05-31", "2015-06-01", "2015-06-02", "2015-06-03", "2015-06-04", "2015-06-05", "2015-06-06", "2015-06-07", "2015-06-08", "2015-06-09", "2015-06-10", "2015-06-11", "2015-06-12", "2015-06-13", "2015-06-14", "2015-06-15", "2015-06-16", "2015-06-17", "2015-06-18", "2015-06-19", "2015-06-20", "2015-06-21", "2015-06-22", "2015-06-23", "2015-06-24", "2015-06-25", "2015-06-26", "2015-06-27", "2015-06-28", "2015-06-29", "2015-06-30", "2015-07-01", "2015-07-02", "2015-07-03", "2015-07-04", "2015-07-05", "2015-07-06", "2015-07-07", "2015-07-08", "2015-07-09", "2015-07-10", "2015-07-11", "2015-07-12", "2015-07-13", "2015-07-14", "2015-07-15", "2015-07-16", "2015-07-17", "2015-07-18", "2015-07-19", "2015-07-20", "2015-07-21", "2015-07-22", "2015-07-23", "2015-07-24", "2015-07-25", "2015-07-26", "2015-07-27", "2015-07-28", "2015-07-29", "2015-07-30", "2015-07-31", "2015-08-01", "2015-08-02", "2015-08-03", "2015-08-04", "2015-08-05", "2015-08-06", "2015-08-07", "2015-08-08", "2015-08-09", "2015-08-10", "2015-08-11", "2015-08-12", "2015-08-13", "2015-08-14", "2015-08-15", "2015-08-16", "2015-08-17", "2015-08-18", "2015-08-19", "2015-08-20", "2015-08-21", "2015-08-22", "2015-08-23", "2015-08-24", "2015-08-25", "2015-08-26", "2015-08-27", "2015-08-28", "2015-08-29", "2015-08-30", "2015-08-31", "2015-09-01", "2015-09-02", "2015-09-03", "2015-09-04", "2015-09-05", "2015-09-06", "2015-09-07", "2015-09-08", "2015-09-09", "2015-09-10", "2015-09-11", "2015-09-12", "2015-09-13", "2015-09-14", "2015-09-15", "2015-09-16", "2015-09-17", "2015-09-18", "2015-09-19", "2015-09-20", "2015-09-21", "2015-09-22", "2015-09-23", "2015-09-24", "2015-09-25", "2015-09-26", "2015-09-27", "2015-09-28", "2015-09-29", ...

# %%
df=cf.datagen.lines(4)
df.iplot(subplots=True,shape=(4,1),shared_xaxes=True,vertical_spacing=.02,fill=True)
# Out:
# <div>
#
#
#             <div id="818e20d4-3517-493d-9563-620b17f90451" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("818e20d4-3517-493d-9563-620b17f90451")) {
#                     Plotly.newPlot(
#                         '818e20d4-3517-493d-9563-620b17f90451',
#                         [{"fill": "tozeroy", "fillcolor": "rgba(226, 74, 51, 0.3)", "line": {"color": "rgba(226, 74, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "BMH.TM", "text": "", "type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-05", "2015-01-06", "2015-01-07", "2015-01-08", "2015-01-09", "2015-01-10", "2015-01-11", "2015-01-12", "2015-01-13", "2015-01-14", "2015-01-15", "2015-01-16", "2015-01-17", "2015-01-18", "2015-01-19", "2015-01-20", "2015-01-21", "2015-01-22", "2015-01-23", "2015-01-24", "2015-01-25", "2015-01-26", "2015-01-27", "2015-01-28", "2015-01-29", "2015-01-30", "2015-01-31", "2015-02-01", "2015-02-02", "2015-02-03", "2015-02-04", "2015-02-05", "2015-02-06", "2015-02-07", "2015-02-08", "2015-02-09", "2015-02-10", "2015-02-11", "2015-02-12", "2015-02-13", "2015-02-14", "2015-02-15", "2015-02-16", "2015-02-17", "2015-02-18", "2015-02-19", "2015-02-20", "2015-02-21", "2015-02-22", "2015-02-23", "2015-02-24", "2015-02-25", "2015-02-26", "2015-02-27", "2015-02-28", "2015-03-01", "2015-03-02", "2015-03-03", "2015-03-04", "2015-03-05", "2015-03-06", "2015-03-07", "2015-03-08", "2015-03-09", "2015-03-10", "2015-03-11", "2015-03-12", "2015-03-13", "2015-03-14", "2015-03-15", "2015-03-16", "2015-03-17", "2015-03-18", "2015-03-19", "2015-03-20", "2015-03-21", "2015-03-22", "2015-03-23", "2015-03-24", "2015-03-25", "2015-03-26", "2015-03-27", "2015-03-28", "2015-03-29", "2015-03-30", "2015-03-31", "2015-04-01", "2015-04-02", "2015-04-03", "2015-04-04", "2015-04-05", "2015-04-06", "2015-04-07", "2015-04-08", "2015-04-09", "2015-04-10"], "xaxis": "x", "y": [-0.08505060996967158, 0.818944702971319, 0.3785756568747107, 1.4926368293183105, 2.997038945948614, 3.311005078062887, 2.6416233570355137, 3.2274258639937936, 0.9497228847940491, 1.2754026946678165, 1.2950540797955299, 1.4794680323247853, 1.6469740781336275, 2.2312829753251067, 2.4348968781338813, 1.3119818896940287, 1.4170510968806156, -0.13075899106499045, -1.3661014637332851, -1.367609778825048, -1.166596268925059, -2.7942313448254334, -3.296983658542583, -2.6101575262975647, -3.049933616714843, -3.128620869780481, -4.7255370451060195, -6.037372797035293, -7.136581739348852, -6.919952181400237, -4.9251080893437695, -6.61281175210628, -7.484009496032631, -6.499359926370145, -5.458733394351731, -6.736490570923615, -9.68246762494121, -9.76221169583336, -10.077122153119104, -9.402502562979308, -7.768811018406506, -6.062004968183468, -5.769313253529393, -6.26412466623144, -6.243086636858613, -6.281349654417966, -7.554799693739909, -6.78077993916769, -7.674513141782569, -10.305328513915557, -9.780369481043195, -10.88725648772575, -10.746891917713892, -10.620440197137825, -10.46088799759096, -11.320282489828553, -11.098302393747282, -11.813100471544331, -11.299162574033069, -9.176374321897956, -7.386793776810212, -8.480409156663246, -9.765284249337888, -10.191806338026332, -10.692243292601269, -10.610253459268163, -10.193441695073888, -7.9780096058518435, -9.300133476921076, -6.513692327851442, -5.370426173308559, -5.5139559094393515, -4.443092114889345, -3.9492577323229665, -4.958768988136572, -5.889899965830875, -6.831368356385367, -6.398245885158229, -5.310210206914472, -5.779770253785843, -6.227139239735694, -5.80267955801639, -5.331942701089755, -5.5902420425096855, -6.019391635728889, -5.872707987152635, -5.660720107364625, -5.546027412077456, -5.1823659633026375, -5.256642370161605, -5.234562911653404, -6.362775123687375, -4.749997733001781, -4.995351821569873, -4.1940447632434985, -4.248272709666335, -3.516651751650638, -4.168110264614256, -4.283073927196961, -3.615996345062975], "yaxis": "y"}, {"fill": "tozeroy", "fillcolor": "rgba(62, 111, 176, 0.3)", "line": {"color": "rgba(62, 111, 176, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "WOB.SE", "text": "", "type": "scatter", "x": ["2015-01-01", "2015-01-02", "2015-01-03", "2015-01-04", "2015-01-0 ...
